# %%
import pandas as pd

# %%
tree = pd.read_csv('Street_Tree_list.csv')

# %%
tree.shape
# Out:
# (196353, 23)

# %%
tree.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196353 entries, 0 to 196352
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   TreeID                     196353 non-null  int64
#  1   qLegalStatus               196296 non-null  object
#  2   qSpecies                   196353 non-null  object
#  3   qAddress                   194862 non-null  object
#  4   SiteOrder                  194551 non-null  float64
#  5   qSiteInfo                  196353 non-null  object
#  6   PlantType                  196353 non-null  object
#  7   qCaretaker                 196353 non-null  object
#  8   qCareAssistant             24685 non-null   object
#  9   PlantDate                  70700 non-null   object
#  10  DBH                        152913 non-null  float64
#  11  PlotSize                   146011 non-null  object
#  12  PermitNotes                53272 non-null   object
# ...

# %%
tree.head()
# Out:
#    TreeID      qLegalStatus  \
# 0  121399    DPW Maintained
# 1   46536    Permitted Site
# 2  251210    DPW Maintained
# 3  254457  Significant Tree
# 4  255073           Private
#
#                                             qSpecies          qAddress  \
# 0            Corymbia ficifolia :: Red Flowering Gum    349X Cargo Way
# 1                                         Tree(s) ::      73 Summer St
# 2  Eucalyptus polyanthemos :: Silver Dollar Eucal...   1170 Ingalls St
# 3                       Dodonaea viscosa :: Hop Bush   1055X Duncan St
# 4                                         Tree(s) ::  173R Glenview Dr
#
#    SiteOrder                     qSiteInfo PlantType qCaretaker  \
# 0        1.0  Sidewalk: Curb side : Cutout      Tree        DPW
# 1        2.0  Sidewalk: Curb side : Cutout      Tree    Private
# 2        2.0  Sidewalk: Curb side : Cutout      Tree        DPW
# 3        2.0              Side Yard : Yard      Tree    Private
# ...

# %%
tree["Zip Codes"]
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 196348       64.0
# 196349    29490.0
# 196350    28859.0
# 196351    28852.0
# 196352    28853.0
# Name: Zip Codes, Length: 196353, dtype: float64

# %%
tree.duplicated().any()
# Out:
# False

# %%
tree["Zip Codes"].drop_duplicates().nunique()
# Out:
# 29

# %% [markdown]
# Above I accessed the Zip Codes Column and used the drop duplicates functing to get rid of duplicate zip codes and than i used the nunique function to count the number of zip codes left in the column I wonder if this would work with out using drop duplicates

# %%
tree["Zip Codes"].nunique()
# Out:
# 29

# %% [markdown]
# turns out you don't need the drop duplicates to count the number of unique items in a column.

# %%
tree.head()
# Out:
#    TreeID      qLegalStatus  \
# 0  121399    DPW Maintained
# 1   46536    Permitted Site
# 2  251210    DPW Maintained
# 3  254457  Significant Tree
# 4  255073           Private
#
#                                             qSpecies          qAddress  \
# 0            Corymbia ficifolia :: Red Flowering Gum    349X Cargo Way
# 1                                         Tree(s) ::      73 Summer St
# 2  Eucalyptus polyanthemos :: Silver Dollar Eucal...   1170 Ingalls St
# 3                       Dodonaea viscosa :: Hop Bush   1055X Duncan St
# 4                                         Tree(s) ::  173R Glenview Dr
#
#    SiteOrder                     qSiteInfo PlantType qCaretaker  \
# 0        1.0  Sidewalk: Curb side : Cutout      Tree        DPW
# 1        2.0  Sidewalk: Curb side : Cutout      Tree    Private
# 2        2.0  Sidewalk: Curb side : Cutout      Tree        DPW
# 3        2.0              Side Yard : Yard      Tree    Private
# ...

# %%
tree.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196353 entries, 0 to 196352
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   TreeID                     196353 non-null  int64
#  1   qLegalStatus               196296 non-null  object
#  2   qSpecies                   196353 non-null  object
#  3   qAddress                   194862 non-null  object
#  4   SiteOrder                  194551 non-null  float64
#  5   qSiteInfo                  196353 non-null  object
#  6   PlantType                  196353 non-null  object
#  7   qCaretaker                 196353 non-null  object
#  8   qCareAssistant             24685 non-null   object
#  9   PlantDate                  70700 non-null   object
#  10  DBH                        152913 non-null  float64
#  11  PlotSize                   146011 non-null  object
#  12  PermitNotes                53272 non-null   object
# ...

# %%
tree.PlotSize.head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: PlotSize, dtype: object

# %%
tree.head()
# Out:
#    TreeID      qLegalStatus  \
# 0  121399    DPW Maintained
# 1   46536    Permitted Site
# 2  251210    DPW Maintained
# 3  254457  Significant Tree
# 4  255073           Private
#
#                                             qSpecies          qAddress  \
# 0            Corymbia ficifolia :: Red Flowering Gum    349X Cargo Way
# 1                                         Tree(s) ::      73 Summer St
# 2  Eucalyptus polyanthemos :: Silver Dollar Eucal...   1170 Ingalls St
# 3                       Dodonaea viscosa :: Hop Bush   1055X Duncan St
# 4                                         Tree(s) ::  173R Glenview Dr
#
#    SiteOrder                     qSiteInfo PlantType qCaretaker  \
# 0        1.0  Sidewalk: Curb side : Cutout      Tree        DPW
# 1        2.0  Sidewalk: Curb side : Cutout      Tree    Private
# 2        2.0  Sidewalk: Curb side : Cutout      Tree        DPW
# 3        2.0              Side Yard : Yard      Tree    Private
# ...

# %%
tree["TreeID"].sum()
# Out:
# 25201372077

# %% [markdown]
# Assuming TreeID column is the number of trees in the area I was able to add them up and get the total number of trees

# %%
tree.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196353 entries, 0 to 196352
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   TreeID                     196353 non-null  int64
#  1   qLegalStatus               196296 non-null  object
#  2   qSpecies                   196353 non-null  object
#  3   qAddress                   194862 non-null  object
#  4   SiteOrder                  194551 non-null  float64
#  5   qSiteInfo                  196353 non-null  object
#  6   PlantType                  196353 non-null  object
#  7   qCaretaker                 196353 non-null  object
#  8   qCareAssistant             24685 non-null   object
#  9   PlantDate                  70700 non-null   object
#  10  DBH                        152913 non-null  float64
#  11  PlotSize                   146011 non-null  object
#  12  PermitNotes                53272 non-null   object
# ...

# %%
tree.head()
# Out:
#    TreeID      qLegalStatus  \
# 0  121399    DPW Maintained
# 1   46536    Permitted Site
# 2  251210    DPW Maintained
# 3  254457  Significant Tree
# 4  255073           Private
#
#                                             qSpecies          qAddress  \
# 0            Corymbia ficifolia :: Red Flowering Gum    349X Cargo Way
# 1                                         Tree(s) ::      73 Summer St
# 2  Eucalyptus polyanthemos :: Silver Dollar Eucal...   1170 Ingalls St
# 3                       Dodonaea viscosa :: Hop Bush   1055X Duncan St
# 4                                         Tree(s) ::  173R Glenview Dr
#
#    SiteOrder                     qSiteInfo PlantType qCaretaker  \
# 0        1.0  Sidewalk: Curb side : Cutout      Tree        DPW
# 1        2.0  Sidewalk: Curb side : Cutout      Tree    Private
# 2        2.0  Sidewalk: Curb side : Cutout      Tree        DPW
# 3        2.0              Side Yard : Yard      Tree    Private
# ...

# %%
tree['PlantType'].duplicated().any()
# Out:
# True

# %%
zipcode = tree['Zip Codes'].nunique()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %% [markdown]
# installing packages

# %%
tree["SiteOrder"].fillna(tree["SiteOrder"].mean(),inplace=True)

# %%
tree.dtypes
# Out:
# TreeID                         int64
# qLegalStatus                  object
# qSpecies                      object
# qAddress                      object
# SiteOrder                    float64
# qSiteInfo                     object
# PlantType                     object
# qCaretaker                    object
# qCareAssistant                object
# PlantDate                     object
# DBH                          float64
# PlotSize                      object
# PermitNotes                   object
# XCoord                       float64
# YCoord                       float64
# Latitude                     float64
# Longitude                    float64
# Location                      object
# Fire Prevention Districts    float64
# Police Districts             float64
# Supervisor Districts         float64
# Zip Codes                    float64
# Neighborhoods (old)          float64
# dtype: object

# %%
tree["SiteOrder"] = tree["SiteOrder"].astype(int)

# %%
tree.dtypes
# Out:
# TreeID                         int64
# qLegalStatus                  object
# qSpecies                      object
# qAddress                      object
# SiteOrder                      int64
# qSiteInfo                     object
# PlantType                     object
# qCaretaker                    object
# qCareAssistant                object
# PlantDate                     object
# DBH                          float64
# PlotSize                      object
# PermitNotes                   object
# XCoord                       float64
# YCoord                       float64
# Latitude                     float64
# Longitude                    float64
# Location                      object
# Fire Prevention Districts    float64
# Police Districts             float64
# Supervisor Districts         float64
# Zip Codes                    float64
# Neighborhoods (old)          float64
# dtype: object

# %%
tree['SiteOrder'].sum()
# Out:
# 895632

# %% [markdown]
# Here I filled in the data using the average amount of trees ordered to fill in missing data and than I converted the type to int to make the numbers look nicer and than added them up to get total number of trees

# %%
tree.loc[tree.isnull().any(axis=1), "Zip Codes"]
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 196347    28859.0
# 196348       64.0
# 196349    29490.0
# 196351    28852.0
# 196352    28853.0
# Name: Zip Codes, Length: 194048, dtype: float64

# %%
tree.dropna(subset=["Zip Codes"])
# Out:
#         TreeID    qLegalStatus  \
# 956       7508  DPW Maintained
# 1041    126345  DPW Maintained
# 1176    183553  DPW Maintained
# 1713    255643  DPW Maintained
# 2329     18916  DPW Maintained
# ...        ...             ...
# 196348     231  DPW Maintained
# 196349   92652  Permitted Site
# 196350  108942  Permitted Site
# 196351  143411  DPW Maintained
# 196352   15238  DPW Maintained
#
#                                               qSpecies            qAddress  \
# 956                    Ulmus parvifolia :: Chinese Elm      2733 Folsom St
# 1041           Corymbia ficifolia :: Red Flowering Gum         504 Clay St
# 1176     Metrosideros excelsa :: New Zealand Xmas Tree     1202 Vicente St
# 1713         Magnolia grandiflora :: Southern Magnolia      1122 Folsom St
# 2329                       Olea europaea :: Olive Tree  2621 Sacramento St
# ...                                                ...                 ...
# ...

# %%
tree
# Out:
#         TreeID    qLegalStatus  \
# 956       7508  DPW Maintained
# 1041    126345  DPW Maintained
# 1176    183553  DPW Maintained
# 1713    255643  DPW Maintained
# 2329     18916  DPW Maintained
# ...        ...             ...
# 196348     231  DPW Maintained
# 196349   92652  Permitted Site
# 196350  108942  Permitted Site
# 196351  143411  DPW Maintained
# 196352   15238  DPW Maintained
#
#                                               qSpecies            qAddress  \
# 956                    Ulmus parvifolia :: Chinese Elm      2733 Folsom St
# 1041           Corymbia ficifolia :: Red Flowering Gum         504 Clay St
# 1176     Metrosideros excelsa :: New Zealand Xmas Tree     1202 Vicente St
# 1713         Magnolia grandiflora :: Southern Magnolia      1122 Folsom St
# 2329                       Olea europaea :: Olive Tree  2621 Sacramento St
# ...                                                ...                 ...
# ...

# %%
tree.filter(items=['id',"qCaretaker"])
# Out:
#        qCaretaker
# 956       Private
# 1041      Private
# 1176      Private
# 1713      Private
# 2329          DPW
# ...           ...
# 196348        DPW
# 196349    Private
# 196350    Private
# 196351    Private
# 196352        DPW
#
# [193271 rows x 1 columns]

# %%
tree.loc[tree.qCaretaker.str.contains('Private','DPW'),['qCaretaker']].count
# Out:
# <bound method DataFrame.count of        qCaretaker
# 956       Private
# 1041      Private
# 1176      Private
# 1713      Private
# 2615      Private
# ...           ...
# 196344    Private
# 196347    Private
# 196349    Private
# 196350    Private
# 196351    Private
#
# [162476 rows x 1 columns]>

# %%
tree["qCaretaker"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# only way i was able to find a way to create a graph was to make a bar graph

# %%
tree.hist(column=['SiteOrder','Zip Codes'])
# Out:
# array([[<AxesSubplot:title={'center':'SiteOrder'}>,
#         <AxesSubplot:title={'center':'Zip Codes'}>]], dtype=object)
